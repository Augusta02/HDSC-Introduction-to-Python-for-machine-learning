# %% [markdown]
# <a href="https://colab.research.google.com/github/Augusta02/HDSC-Introduction-to-Python-for-machine-learning/blob/master/HDSC_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-94f1b696-7573-471c-8dcf-3a8ad7b42825" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94f1b696-7573-471c-8dcf-3a8ad7b42825">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Hamoye.csv to Hamoye.csv

# %%
import io
import pandas as pd
df= pd.read_csv('Hamoye.csv', encoding='latin-1')
df.head()
# Out:
#    Area Code     Area  Item Code  ...     Y2016     Y2017     Y2018
# 0          4  Algeria       2501  ...  40551.00  41389.00  42228.00
# 1          4  Algeria       2501  ...      0.00      0.00      0.00
# 2          4  Algeria       2901  ...   3372.00   3341.00   3322.00
# 3          4  Algeria       2901  ...     94.72     92.82     91.83
# 4          4  Algeria       2901  ...     77.40     80.19     77.28
#
# [5 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df['Y2014'].mean()
# Out:
# 134.19628213767805

# %%
df['Y2014'].median()
# Out:
# 0.09

# %%
df['Y2014'].fillna(df['Y2014'].median())
# Out:
# 0        38924.00
# 1            0.00
# 2         3377.00
# 3           94.90
# 4           80.06
#            ...
# 60938       42.00
# 60939        3.06
# 60940        3.00
# 60941        0.10
# 60942        0.04
# Name: Y2014, Length: 60943, dtype: float64

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
total2014 = df.groupby('Item').sum('Y2014').loc['Animal fats']
total2014['Y2014']
# Out:
# 209460.54

# %%
total2017 =df.groupby('Item').sum('Y2017').loc['Animal fats']
total2017['Y2017']
# Out:
# 269617.53

# %%
df.describe()
# Out:
#           Area Code     Item Code  ...          Y2017          Y2018
# count  60943.000000  60943.000000  ...   59437.000000   59507.000000
# mean     134.265576   2687.176706  ...     140.917765     143.758381
# std       72.605709    146.055739  ...    1671.862359    1710.782658
# min        4.000000   2501.000000  ...   -1582.000000   -3396.000000
# 25%       74.000000   2562.000000  ...       0.000000       0.000000
# 50%      136.000000   2630.000000  ...       0.100000       0.070000
# 75%      195.000000   2775.000000  ...       9.000000       9.000000
# max      276.000000   2961.000000  ...  190873.000000  195875.000000
#
# [8 rows x 8 columns]

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code  ...     Y2016     Y2017     Y2018
# Area Code      1.000000  -0.005159     -0.000209  ...  0.005247  0.005006  0.005665
# Item Code     -0.005159   1.000000     -0.024683  ...  0.020109  0.021494  0.021314
# Element Code  -0.000209  -0.024683      1.000000  ...  0.023444  0.024254  0.024279
# Y2014          0.006164   0.021722      0.024457  ...  0.996081  0.995230  0.994872
# Y2015          0.005472   0.020857      0.023889  ...  0.995739  0.988048  0.988208
# Y2016          0.005247   0.020109      0.023444  ...  1.000000  0.992785  0.992757
# Y2017          0.005006   0.021494      0.024254  ...  0.992785  1.000000  0.998103
# Y2018          0.005665   0.021314      0.024279  ...  0.992757  0.998103  1.000000
#
# [8 rows x 8 columns]

# %%
totalimport= df.groupby('Element').sum('Y2017').loc['Import Quantity']
totalimport
# Out:
# Area Code         688174.00
# Item Code       13795966.00
# Element Code    28834929.00
# Y2014             274144.48
# Y2015             267018.46
# Y2016             286582.78
# Y2017             294559.09
# Y2018             287997.09
# Name: Import Quantity, dtype: float64

# %%
totalproduction= df.groupby('Element').sum().loc['Production']
totalproduction
# Out:
# Area Code         526751.00
# Item Code       10450053.00
# Element Code    21388191.00
# Y2014            1931287.75
# Y2015            1947019.39
# Y2016            1943537.15
# Y2017            2030056.89
# Y2018            2075072.89
# Name: Production, dtype: float64

# %%
total = df.groupby('Element').sum()
total
# Out:
#                                         Area Code  ...       Y2018
# Element                                            ...
# Domestic supply quantity                   708993  ...  2161192.10
# Export Quantity                            599910  ...   181594.80
# Fat supply quantity (g/capita/day)         675050  ...    10258.69
# Feed                                       176272  ...   233489.68
# Food                                       663295  ...  1303841.28
# Food supply (kcal/capita/day)              674057  ...   455261.00
# Food supply quantity (kg/capita/yr)        658446  ...    49056.85
# Import Quantity                            688174  ...   287997.09
# Losses                                     274353  ...   163902.00
# Other uses (non-food)                      235554  ...    91300.97
# Processing                                 271940  ...   308429.00
# Production                                 526751  ...  2075072.89
# ...

# %%
total_ =df.groupby('Area').sum('Import Quantity')
total_
# Out:
#                              Area Code  Item Code  ...       Y2017       Y2018
# Area                                               ...
# Algeria                           5252    3532053  ...   325644.27   341729.98
# Angola                            9968    3819908  ...   229159.57   235206.68
# Benin                            68105    3453692  ...   124771.22   124960.70
# Botswana                         27560    3704902  ...    22101.30    23129.08
# Burkina Faso                    328297    3778795  ...   101855.07   112970.72
# Cabo Verde                       44100    3396746  ...    14650.74    14622.60
# Cameroon                         46720    3916078  ...   232030.43   233022.93
# Central African Republic         49728    3607546  ...    29937.00    30101.57
# Chad                             52377    3606529  ...    71594.68    72282.24
# Comoros                           2025     124514  ...       59.84       59.84
# ...

# %%
unique_ = df['Area'].unique()
len(unique_)
# Out:
# 49

# %%
df.shape
# Out:
# (60943, 12)
